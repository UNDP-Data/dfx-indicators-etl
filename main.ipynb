# %% [markdown]
# # DFx ETL Pipeline
#
# ## ETL
#
# A generic notebook to execute ETL pipelines for the supported data providers.

# %% [markdown]
# ### Libraries

# %%
import logging

from dfx_etl.pipelines import get_pipeline

# %% [markdown]
# ### Configuration

# %%
PIPELINE_NAME = 'world_bank_wdi'
# set the logging level
logging.basicConfig(
    level=logging.WARNING,  # logging.INFO or logging.WARNING
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler()],
)

# %%
pipeline = get_pipeline(PIPELINE_NAME)
pipeline
# Out:
# Pipeline(retriever=Retriever(uri=PosixPath('inputs/WDI_CSV/WDICSV.csv'), headers=None), transformer=Transformer())

# %% [markdown]
# ### Extract

# %%
pipeline.retrieve()
print("Shape:", pipeline.df_raw.shape)
display(pipeline.df_raw.head())
# Out:
# Shape: (402458, 69)
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2015       2016       2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  18.145833  18.685118  19.205632
# 1   NaN   NaN   NaN   NaN   NaN  ...   7.259936   7.606712   7.926604
# 2   NaN   NaN   NaN   NaN   NaN  ...  38.741988  39.052626  39.321068
# 3   NaN   NaN   NaN   NaN   NaN  ...  33.922276  38.859598  40.223744
# 4   NaN   NaN   NaN   NaN   NaN  ...  16.495064  24.584906  25.375037
#
#         2018       2019       2020       2021       2022       2023  2024
# 0  19.742772  20.332679  20.862800  21.419621  21.996456  22.541440   NaN
# 1   8.309896   8.704591   9.106640   9.480804   9.903209  10.288154   NaN
# 2  39.649534  39.968299  40.354628  40.723805  41.026351  41.289974   NaN
# 3  43.035073  44.390861  46.282371  48.127211  48.801258  50.667516   NaN
# 4  26.941984  28.983183  30.909991  32.709837  33.747222  35.240236   NaN
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Transform

# %%
pipeline.transform()
print("Shape:", pipeline.df_transformed.shape)
display(pipeline.df_transformed.head())
# Out:
# Shape: (1732232, 7)
#   country_code                                     indicator_name  year  \
# 0          AFG  Access to clean fuels and technologies for coo...  2015
# 1          AFG  Access to clean fuels and technologies for coo...  2015
# 2          AFG  Access to clean fuels and technologies for coo...  2015
# 3          AFG  Access to electricity (% of population) [EG.EL...  2015
# 4          AFG  Access to electricity, rural (% of rural popul...  2015
#
#    value        provider disaggregation source
# 0   27.5  world_bank_wdi          Total   <NA>
# 1   11.1  world_bank_wdi          Total   <NA>
# 2   79.4  world_bank_wdi          Total   <NA>
# 3   71.5  world_bank_wdi          Total   <NA>
# 4   64.6  world_bank_wdi          Total   <NA>

# %% [markdown]
# ### Load

# %%
pipeline.load();
