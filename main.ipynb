# %% [markdown]
# # DFx ETL Pipeline
#
# ## ETL
#
# A generic notebook to execure ETL pipelines for supported data sources.

# %% [markdown]
# ### Libraries

# %%
import logging

from dfx_etl.storage import get_storage
from dfx_etl.pipelines import unaids_org as source, Pipeline  # change the source as needed

# %% [markdown]
# ### Configuration

# %%
# set the logging level
logging.basicConfig(
    level=logging.WARNING,  # logging.INFO or logging.WARNING
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler()],
)

# %%
# get the storage object automatically
storage = get_storage()
storage
# Out:
# AzureStorage(account_name='dfx', container_name='etl-pipeline')

# %%
# specify pipeline details
pipeline = Pipeline(
    url="https://kpatlas.unaids.org",
    retriever=source.Retriever(storage=storage),
    transformer=source.Transformer(),
    storage=storage,
)

# %% [markdown]
# ### Extract

# %%
pipeline.retrieve()
print("Shape:", pipeline.df_raw.shape)
display(pipeline.df_raw.head())
# Out:
# Shape: (50977, 11)
#                                            Indicator    Unit Subgroup  \
# 0  Adolescents and young men who have sex with me...  Number    15-19
# 1  Adolescents and young men who have sex with me...  Number    15-19
# 2  Adolescents and young men who have sex with me...  Number    15-19
# 3  Adolescents and young men who have sex with me...  Number    15-19
# 4  Adolescents and young men who have sex with me...  Number    15-19
#
#                    Area Area ID  Time Period       Source  Data value  \
# 0           Afghanistan     AFG         2019  UNAIDS_GAM_     24600.0
# 1                Angola     AGO         2019  UNAIDS_GAM_     22500.0
# 2               Albania     ALB         2019  UNAIDS_GAM_      1000.0
# 3  United Arab Emirates     ARE         2019  UNAIDS_GAM_       140.0
# 4             Argentina     ARG         2019  UNAIDS_GAM_     25400.0
#
#   Formatted  Data_Denominator  \
# 0       NaN               0.0
# 1       NaN               0.0
# 2       NaN               0.0
# 3       NaN               0.0
# 4       NaN               0.0
#
#                                             Footnote
# 0  Source: Johnston LG Nguyen VK Balakrishnan S L...
# 1  Source: Johnston LG Nguyen VK Balakrishnan S L...
# 2  Source: Johnston LG Nguyen VK Balakrishnan S L...
# 3  Source: Johnston LG Nguyen VK Balakrishnan S L...
# 4  Source: Johnston LG Nguyen VK Balakrishnan S L...

# %% [markdown]
# ### Transform

# %%
pipeline.transform()
print("Shape:", pipeline.df_transformed.shape)
display(pipeline.df_transformed.head())
# Out:
# Shape: (10864, 5)
#                                       indicator_name country_code  year  \
# 0  Antiretroviral therapy coverage among men who ...          AUS  2016
# 1  Antiretroviral therapy coverage among men who ...          AUT  2016
# 2  Antiretroviral therapy coverage among men who ...          AUT  2020
# 3  Antiretroviral therapy coverage among men who ...          AUT  2021
# 4  Antiretroviral therapy coverage among men who ...          AUT  2022
#
#        value                       source
# 0  78.000000  https://kpatlas.unaids.org/
# 1  74.000000  https://kpatlas.unaids.org/
# 2  90.200000  https://kpatlas.unaids.org/
# 3  94.089974  https://kpatlas.unaids.org/
# 4  93.300000  https://kpatlas.unaids.org/

# %% [markdown]
# ### Validate

# %%
pipeline.validate()
print("Shape:", pipeline.df_validated.shape)
display(pipeline.df_validated.head())
# Out:
# Shape: (10864, 5)
#                                       indicator_name country_code  year  \
# 0  Antiretroviral therapy coverage among men who ...          AUS  2016
# 1  Antiretroviral therapy coverage among men who ...          AUT  2016
# 2  Antiretroviral therapy coverage among men who ...          AUT  2020
# 3  Antiretroviral therapy coverage among men who ...          AUT  2021
# 4  Antiretroviral therapy coverage among men who ...          AUT  2022
#
#        value                       source
# 0  78.000000  https://kpatlas.unaids.org/
# 1  74.000000  https://kpatlas.unaids.org/
# 2  90.200000  https://kpatlas.unaids.org/
# 3  94.089974  https://kpatlas.unaids.org/
# 4  93.300000  https://kpatlas.unaids.org/

# %% [markdown]
# ### Load

# %%
pipeline.load();
