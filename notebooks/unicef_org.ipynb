# %% [markdown]
# # DFx ETL Pipeline
#
# ## unicef.org
#
# An ETL pipeline for [UNICEF Indicator Data Warehouse](https://sdmx.data.unicef.org) from United Nations Children's Fund (UNICEF).

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
from tqdm import tqdm

from dfpp.sources import unicef_org as source
from dfpp.storage import AzureStorage as Storage

DATAFLOW = "UNICEF,GLOBAL_DATAFLOW,1.0"
storage = Storage()

# %% [markdown]
# ### Extract

# %%
df_metadata = source.get_series_metadata(DATAFLOW)
print("Shape:", df_metadata.shape)
display(df_metadata.head())
# Out:
# Shape: (354, 3)
#                      series_id  \
# 0              HVA_PED_EID_NUM
# 1  MG_RFGS_CNTRY_ASYLM_PER1000
# 2            DM_POP_CHILD_PROP
# 3       ECON_GVT_EDU_EXP_PTEXP
# 4                 MNCH_INSTDEL
#
#                                          series_name  \
# 0  Reported number of infants born to pregnant wo...
# 1      Refugees by host country, per 1000 population
# 2  Children population as proportion of total pop...
# 3  government expenditure on education (% governm...
# 4  Institutional deliveries - percentage of deliv...
#
#                                   series_description
# 0  Reported number of infants born to pregnant wo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Institutional deliveries - percentage of deliv...

# %%
data = []
for series_id in tqdm(df_metadata["series_id"]):
    try:
        df = source.get_series_data(DATAFLOW, indicator=series_id)
        df["series_id"] = series_id
    except Exception as error:
        print(series_id, error)
        continue
    data.append(df)
df_raw = pd.concat(data, axis=0, ignore_index=True)
print("Shape:", df_raw.shape)
display(df_raw.head())
# Out:
# 100%|██████████| 5/5 [00:07<00:00,  1.41s/it]
# Shape: (29287, 31)
#        REF_AREA         Geographic area    INDICATOR  \
# 0  SDGRC_ECA_CA  (SDGRC) Central Africa  WS_HCF_WM-B
# 1  SDGRC_ECA_CA  (SDGRC) Central Africa  WS_HCF_WM-B
# 2  SDGRC_ECA_CA  (SDGRC) Central Africa  WS_HCF_WM-B
# 3  SDGRC_ECA_CA  (SDGRC) Central Africa  WS_HCF_WM-B
# 4  SDGRC_ECA_CA  (SDGRC) Central Africa  WS_HCF_WM-B
#
#                                            Indicator SEX    Sex  TIME_PERIOD  \
# 0  Proportion of health care facilities with basi...  _T  Total         2010
# 1  Proportion of health care facilities with basi...  _T  Total         2011
# 2  Proportion of health care facilities with basi...  _T  Total         2012
# 3  Proportion of health care facilities with basi...  _T  Total         2013
# 4  Proportion of health care facilities with basi...  _T  Total         2014
#
#    OBS_VALUE  UNIT_MULTIPLIER Unit multiplier  ...  \
# 0  39.278759              NaN             NaN  ...
# 1  40.183521              NaN             NaN  ...
# 2  41.115047              NaN             NaN  ...
# 3  39.322906              NaN             NaN  ...
# 4  37.164085              NaN             NaN  ...
#
#                                          DATA_SOURCE SOURCE_LINK CUSTODIAN  \
# 0  WHO/UNICEF Joint Monitoring Programme () WASH ...         NaN       NaN
# 1  WHO/UNICEF Joint Monitoring Programme () WASH ...         NaN       NaN
# 2  WHO/UNICEF Joint Monitoring Programme () WASH ...         NaN       NaN
# 3  WHO/UNICEF Joint Monitoring Programme () WASH ...         NaN       NaN
# 4  WHO/UNICEF Joint Monitoring Programme () WASH ...         NaN       NaN
#
#   TIME_PERIOD_METHOD  \
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
#   Time period activity related to when the data are collected REF_PERIOD  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#    COVERAGE_TIME  AGE  Current age    series_id
# 0            NaN   _T        Total  WS_HCF_WM-B
# 1            NaN   _T        Total  WS_HCF_WM-B
# 2            NaN   _T        Total  WS_HCF_WM-B
# 3            NaN   _T        Total  WS_HCF_WM-B
# 4            NaN   _T        Total  WS_HCF_WM-B
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Transform

# %%
df_transformed = source.transform(df_raw)
print("Shape:", df_transformed.shape)
display(df_transformed.head())
# Out:
# 2025-08-31 22:35:50,628 - WARNING - column_name_template - Filling missing canonical column prop_observation_type with None
# 2025-08-31 22:35:50,629 - WARNING - column_name_template - Filling missing canonical column prop_value_label with None
# Shape: (23460, 11)
#                          source    series_id  \
# 0  https://sdmx.data.unicef.org  WS_HCF_WM-B
# 1  https://sdmx.data.unicef.org  WS_HCF_WM-B
# 2  https://sdmx.data.unicef.org  WS_HCF_WM-B
# 3  https://sdmx.data.unicef.org  WS_HCF_WM-B
# 4  https://sdmx.data.unicef.org  WS_HCF_WM-B
#
#                                          series_name disagr_sex disagr_age  \
# 0  Proportion of health care facilities with basi...      Total      Total
# 1  Proportion of health care facilities with basi...      Total      Total
# 2  Proportion of health care facilities with basi...      Total      Total
# 3  Proportion of health care facilities with basi...      Total      Total
# 4  Proportion of health care facilities with basi...      Total      Total
#
#   alpha_3_code prop_unit prop_observation_type  year  value prop_value_label
# 0          AFG         %                  None  2016   82.0             None
# 1          AFG         %                  None  2017   82.0             None
# 2          AFG         %                  None  2018   82.0             None
# 3          AFG         %                  None  2019   82.0             None
# 4          AFG         %                  None  2020   82.0             None

# %% [markdown]
# ### Load

# %%
for series_id, df in tqdm(df_transformed.groupby("series_id")):
    df.name = series_id
    storage.publish_dataset(df, folder_path=source.SOURCE_NAME)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 112.15it/s]
