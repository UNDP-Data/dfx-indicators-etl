# %% [markdown]
# # DFx ETL Pipeline
#
# ## unaids.org
#
# An ETL pipeline for [Key Population Atlas](https://kpatlas.unaids.org) from the Joint United Nations Programme on HIV and AIDS (UNAIDS).

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
from tqdm import tqdm

from dfpp.sources import unaids_org as source
from dfpp.storage import LocalStorage as Storage

storage = Storage()

# %% [markdown]
# ### Extract

# %%
df_raw = pd.read_csv("~/Downloads/KPAtlasDB_2025_en.zip")
print("Shape:", df_raw.shape)
display(df_raw.head())

# %% [markdown]
# ### Transform

# %%
df_transformed = source.transform(df_raw)
print("Shape:", df_transformed.shape)
display(df_transformed.head())

# %% [markdown]
# ### Load

# %%
for series_id, df in tqdm(df_transformed.groupby("series_id")):
    df.name = series_id
    storage.publish_dataset(df, folder_path=source.SOURCE_NAME)
