# %%
from io import BytesIO
import country_converter as coco
import pandas as pd
import string

from dfpp.storage import StorageManager
from dfpp.publishing import publish_series

from dfpp.transformation.column_name_template import (
    CANONICAL_COLUMN_NAMES,
    SERIES_PROPERTY_PREFIX,
    DIMENSION_COLUMN_PREFIX,
    SexEnum,
    sort_columns_canonically,
    ensure_canonical_columns,
)

cc = coco.CountryConverter()
BASE_URL = "https://www.healthdata.org/"
FILE_PATH = "backup/sources/IHME-GBD_2021_DATA-c13547d7-1.csv"
SOURCE_NAME = "healthdata_org"

# %%
async with StorageManager() as storage_manager:
    series_bytes = await storage_manager.read_blob(path=FILE_PATH)
    df_source = pd.read_csv(BytesIO(series_bytes))
# Out:
# 2024-11-13 23:46:21,175 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/backup/sources/IHME-GBD_2021_DATA-c13547d7-1.csv?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b8917342-a208-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# No body was attached to the request
# 2024-11-13 23:46:21,547 - INFO - _universal - Response status: 200
# Response headers:
#     'Content-Length': '43483471'
#     'Content-Type': 'text/csv'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:01:53 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DD042666B4C00A"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'a4bac7fb-901e-0033-5115-36f082000000'
#     'x-ms-client-request-id': 'b8917342-a208-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Access-Control-Expose-Headers': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:46:20 GMT'
# 2024-11-13 23:46:21,549 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/backup/sources/IHME-GBD_2021_DATA-c13547d7-1.csv?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b8ca825e-a208-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# No body was attached to the request
# 2024-11-13 23:46:21,710 - INFO - _universal - Response status: 206
# Response headers:
#     'Content-Length': '33554432'
#     'Content-Type': 'text/csv'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:01:53 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DD042666B4C00A"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'a4bac822-901e-0033-6f15-36f082000000'
#     'x-ms-client-request-id': 'b8ca825e-a208-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Access-Control-Expose-Headers': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:46:21 GMT'
# 2024-11-13 23:46:25,681 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/backup/sources/IHME-GBD_2021_DATA-c13547d7-1.csv?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'If-Match': '"0x8DD042666B4C00A"'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bb4108fa-a208-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# No body was attached to the request
# 2024-11-13 23:46:25,821 - INFO - _universal - Response status: 206
# Response headers:
#     'Content-Length': '4194304'
#     'Content-Type': 'text/csv'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:01:53 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DD042666B4C00A"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'a4bad165-901e-0033-0215-36f082000000'
#     'x-ms-client-request-id': 'bb4108fa-a208-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Access-Control-Expose-Headers': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:46:25 GMT'
# 2024-11-13 23:46:26,101 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/backup/sources/IHME-GBD_2021_DATA-c13547d7-1.csv?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'If-Match': '"0x8DD042666B4C00A"'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bb811a58-a208-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# No body was attached to the request
# 2024-11-13 23:46:26,222 - INFO - _universal - Response status: 206
# Response headers:
#     'Content-Length': '4194304'
#     'Content-Type': 'text/csv'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:01:53 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DD042666B4C00A"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'a4bad28b-901e-0033-0615-36f082000000'
#     'x-ms-client-request-id': 'bb811a58-a208-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Access-Control-Expose-Headers': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:46:25 GMT'
# 2024-11-13 23:46:26,475 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/backup/sources/IHME-GBD_2021_DATA-c13547d7-1.csv?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'If-Match': '"0x8DD042666B4C00A"'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bbba2366-a208-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# No body was attached to the request
# 2024-11-13 23:46:26,584 - INFO - _universal - Response status: 206
# Response headers:
#     'Content-Length': '1540431'
#     'Content-Type': 'text/csv'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:01:53 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DD042666B4C00A"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'a4bad3a7-901e-0033-7615-36f082000000'
#     'x-ms-client-request-id': 'bbba2366-a208-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Access-Control-Expose-Headers': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:46:25 GMT'

# %%
df = df_source.copy()
df["source"] = BASE_URL
df["alpha_3_code"] = cc.pandas_convert(df["location_name"], to="ISO3")

df["series_name"] = df["measure_name"] + ", " + df["cause_name"]

df["series_id"] = (
    df["series_name"]
    .str.replace(f"[{string.punctuation}]", "", regex=True)
    .str.replace(" ", "_")
    .str.lower()
)

df.rename(
    columns={
        "val": "value",
        "metric_name": SERIES_PROPERTY_PREFIX + "unit",
        "sex_name": DIMENSION_COLUMN_PREFIX + "sex",
        "age_name": DIMENSION_COLUMN_PREFIX + "age",
        "cause_name": DIMENSION_COLUMN_PREFIX + "cause",
    },
    inplace=True,
)

df[DIMENSION_COLUMN_PREFIX + "sex"] = df[DIMENSION_COLUMN_PREFIX + "sex"].map(
    {
        "Male": SexEnum.MALE.value,
        "Female": SexEnum.FEMALE.value,
        "Both sexes": SexEnum.BOTH.value,
        "All sexes": SexEnum.TOTAL.value,
    }
)

disagr_columns = [
    col
    for col in df.columns
    if col.startswith(DIMENSION_COLUMN_PREFIX) and col not in CANONICAL_COLUMN_NAMES
]

property_columns = [
    col
    for col in df.columns
    if col.startswith(SERIES_PROPERTY_PREFIX) and col not in CANONICAL_COLUMN_NAMES
]


df = ensure_canonical_columns(df)
df = df[CANONICAL_COLUMN_NAMES + disagr_columns + property_columns]
df = sort_columns_canonically(df)
assert df.drop("value", axis=1).duplicated().sum() == 0
# Out:
# 2024-11-13 23:46:27,379 - WARNING - country_converter - Global not found in regex
# 2024-11-13 23:46:28,487 - WARNING - column_name_template - Filling missing canonical column prprty_observation_type with None

# %%
for series_id, df_series in df.groupby("series_id"):
    await publish_series(series_id, df_series, source_folder=SOURCE_NAME)
# Out:
# 2024-11-13 23:51:16,676 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/deaths_cardiovascular_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '654236'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '68b2c118-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:17,834 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:17 GMT'
#     'Etag': '"0x8DD042D4DA073C9"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '15164270-701e-002b-1a16-362fe5000000'
#     'x-ms-client-request-id': '68b2c118-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:17 GMT'
# 2024-11-13 23:51:18,118 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/deaths_chronic_respiratory_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '679247'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '698f6118-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:19,020 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:19 GMT'
#     'Etag': '"0x8DD042D4E5A3354"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'ec0fa9ec-b01e-0046-3316-369bae000000'
#     'x-ms-client-request-id': '698f6118-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:18 GMT'
# 2024-11-13 23:51:19,319 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/deaths_digestive_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '629869'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6a4691da-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:20,278 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:20 GMT'
#     'Etag': '"0x8DD042D4F188608"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'da254296-c01e-002e-5c16-36fd3e000000'
#     'x-ms-client-request-id': '6a4691da-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:20 GMT'
# 2024-11-13 23:51:20,384 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/deaths_neurological_disorders.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '649376'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6ae91cfc-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:21,398 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:21 GMT'
#     'Etag': '"0x8DD042D4FC52812"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '991e4497-c01e-005c-7d16-36fa71000000'
#     'x-ms-client-request-id': '6ae91cfc-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:21 GMT'
# 2024-11-13 23:51:21,540 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/deaths_other_noncommunicable_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '660589'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6b99838a-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:22,571 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:22 GMT'
#     'Etag': '"0x8DD042D507831D8"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '03b330b8-801e-004d-4a16-3660c5000000'
#     'x-ms-client-request-id': '6b99838a-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:22 GMT'
# 2024-11-13 23:51:22,684 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/prevalence_cardiovascular_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '487212'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6c4812ec-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:23,542 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:23 GMT'
#     'Etag': '"0x8DD042D510716EB"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '9ad71d4e-a01e-0075-3b16-36c405000000'
#     'x-ms-client-request-id': '6c4812ec-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:22 GMT'
# 2024-11-13 23:51:23,637 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/prevalence_chronic_respiratory_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '506124'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6cd97f48-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:24,596 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:24 GMT'
#     'Etag': '"0x8DD042D51ACDC1B"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'f3ddd9ba-a01e-005a-2316-36c9ce000000'
#     'x-ms-client-request-id': '6cd97f48-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:24 GMT'
# 2024-11-13 23:51:24,682 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/prevalence_digestive_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '468359'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6d79031a-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:25,430 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:25 GMT'
#     'Etag': '"0x8DD042D522C0C08"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'eada1c20-f01e-0078-1116-360cd1000000'
#     'x-ms-client-request-id': '6d79031a-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:24 GMT'
# 2024-11-13 23:51:25,518 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/prevalence_neurological_disorders.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '483447'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6df891c0-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:26,321 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:26 GMT'
#     'Etag': '"0x8DD042D52B43B51"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '88847581-f01e-0025-4816-360655000000'
#     'x-ms-client-request-id': '6df891c0-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:25 GMT'
# 2024-11-13 23:51:26,409 - INFO - _universal - Request URL: 'https://sdgigeneralstorage.blob.core.windows.net/dfx-etl-pipeline-dev/test/healthdata_org/parquet/prevalence_other_noncommunicable_diseases.parquet?sv=REDACTED&st=REDACTED&se=REDACTED&sr=REDACTED&sp=REDACTED&sig=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '516256'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '6e808314-a209-11ef-8bcd-acbc327b2b3d'
#     'User-Agent': 'azsdk-python-storage-blob/12.21.0 Python/3.11.9 (macOS-10.16-x86_64-i386-64bit)'
# A body is sent with the request
# 2024-11-13 23:51:27,235 - INFO - _universal - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 13 Nov 2024 21:51:27 GMT'
#     'Etag': '"0x8DD042D533FC582"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4ce4ffc8-f01e-000a-0616-360b9e000000'
#     'x-ms-client-request-id': '6e808314-a209-11ef-8bcd-acbc327b2b3d'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 13 Nov 2024 21:51:26 GMT'
