# %% [markdown]
# # DFx ETL Pipeline
#
# ## healthdata.org
#
# An ETL pipeline for [Global Burden of Disease Study dataset](https://ghdx.healthdata.org/gbd-2021) from the Global Health Data Exchange (GHDx).

# %% [markdown]
# ### Libraries

# %%
from dotenv import load_dotenv
from tqdm import tqdm

load_dotenv()
from dfpp.storage import AzureStorage as Storage
from dfpp.sources import healthdata_org as source

storage = Storage()
SOURCE_NAME = "healthdata_org"

# %% [markdown]
# ### Extract

# %%
df_raw = storage.read_dataset(
    storage.join_path("manual/IHME-GBD_2021_DATA-c13547d7-1.csv")
)
print("Shape:", df_raw.shape)
display(df_raw.head())
# Out:
# Shape: (303400, 16)
#    measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0           1       Deaths          349     Greenland       1     Male
# 1           1       Deaths          349     Greenland       2   Female
# 2           1       Deaths          349     Greenland       1     Male
# 3           1       Deaths          349     Greenland       2   Female
# 4           1       Deaths           84       Ireland       1     Male
#
#    age_id  age_name  cause_id               cause_name  metric_id metric_name  \
# 0      22  All ages       526       Digestive diseases          1      Number
# 1      22  All ages       526       Digestive diseases          1      Number
# 2      22  All ages       526       Digestive diseases          3        Rate
# 3      22  All ages       526       Digestive diseases          3        Rate
# 4      22  All ages       491  Cardiovascular diseases          1      Number
#
#    year          val        upper        lower
# 0  1980     6.965934     8.394566     5.592003
# 1  1980     7.915022     9.458732     6.676566
# 2  1980    25.770021    31.055151    20.687252
# 3  1980    34.754251    41.532561    29.316287
# 4  1980  8929.646298  9166.850692  8651.144217

# %% [markdown]
# ### Transform

# %%
df_transformed = source.transform(df_raw)
print("Shape:", df_transformed.shape)
display(df_transformed.head())
# Out:
# 2025-07-29 13:49:22,156 - WARNING - country_converter - Global not found in regex
# 2025-07-29 13:49:24,819 - WARNING - column_name_template - Filling missing canonical column prop_observation_type with None
# Shape: (303400, 12)
#                         source                       series_id  \
# 0  https://www.healthdata.org/       deaths_digestive_diseases
# 1  https://www.healthdata.org/       deaths_digestive_diseases
# 2  https://www.healthdata.org/       deaths_digestive_diseases
# 3  https://www.healthdata.org/       deaths_digestive_diseases
# 4  https://www.healthdata.org/  deaths_cardiovascular_diseases
#
#                        series_name disagr_sex disagr_age  \
# 0       Deaths, Digestive diseases       male   All ages
# 1       Deaths, Digestive diseases     female   All ages
# 2       Deaths, Digestive diseases       male   All ages
# 3       Deaths, Digestive diseases     female   All ages
# 4  Deaths, Cardiovascular diseases       male   All ages
#
#               disagr_cause alpha_3_code prop_unit prop_observation_type  year  \
# 0       Digestive diseases          GRL    Number                  None  1980
# 1       Digestive diseases          GRL    Number                  None  1980
# 2       Digestive diseases          GRL      Rate                  None  1980
# 3       Digestive diseases          GRL      Rate                  None  1980
# 4  Cardiovascular diseases          IRL    Number                  None  1980
#
#          value  prop_value_label
# 0     6.965934               NaN
# 1     7.915022               NaN
# 2    25.770021               NaN
# 3    34.754251               NaN
# 4  8929.646298               NaN

# %%
df_transformed[['source', 'series_id', 'series_name']].drop_duplicates().to_clipboard(index=False)

# %% [markdown]
# ### Load

# %%
for series_id, df in tqdm(df_transformed.groupby("series_id")):
    df.name = series_id
    storage.publish_dataset(df, folder_path=SOURCE_NAME)
# Out:
# 100%|██████████| 10/10 [00:15<00:00,  1.54s/it]
